# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd

from nba_api.stats.endpoints import teamgamelogs
from nba_api.stats.static import teams
nba_teams = teams.get_teams()
teamIDs = [team['id'] for team in nba_teams]
#bookies = ['Pinnacle Sports','5Dimes','Bookmaker','BetOnline','Heritage','Intertops','YouWager','JustBet','Sportsbetting','Bovada']

# %%
#bets = pd.read_csv(r'.\data\betting.csv')
games = []
games.append(pd.read_csv(r'.\data\2014-15.csv', index_col=0))
games.append(pd.read_csv(r'.\data\2015-16.csv', index_col=0))
games.append(pd.read_csv(r'.\data\2016-17.csv', index_col=0))
games.append(pd.read_csv(r'.\data\2017-18.csv', index_col=0))
games.append(pd.read_csv(r'.\data\2018-19.csv', index_col=0))
games.append(pd.read_csv(r'.\data\2019-20.csv', index_col=0))
games.append(pd.read_csv(r'.\data\2020-21.csv', index_col=0))
games[0].head()
# Out:
#   SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION             TEAM_NAME   GAME_ID  \
# 0     2014-15  1610612747               LAL    Los Angeles Lakers  21400003
# 1     2014-15  1610612759               SAS     San Antonio Spurs  21400002
# 2     2014-15  1610612740               NOP  New Orleans Pelicans  21400001
# 1     2014-15  1610612753               ORL         Orlando Magic  21400001
# 2     2014-15  1610612745               HOU       Houston Rockets  21400003
#
#     GAME_DATE      MATCHUP WL   MIN       FGM  ...      PTS-  PLUS_MINUS-  \
# 0  2014-10-28  LAL vs. HOU  L  48.0  0.583333  ...  2.250000         18.0
# 1  2014-10-28  SAS vs. DAL  W  48.0  0.770833  ...  2.083333         -1.0
# 2  2014-10-28  NOP vs. ORL  W  48.0  0.854167  ...  1.750000        -17.0
# 1  2014-10-28    ORL @ NOP  L  48.0  0.666667  ...  2.104167         17.0
# 2  2014-10-28    HOU @ LAL  W  48.0  0.645833  ...  1.875000        -18.0
#
#    WPCT-  Away        Date  Home  MLA    MLH     OU  Spread
# ...

# %%
m = [[[{},{},{}],[{},{},{}]],
     [[{},{},{}],[{},{},{}]],
     [[{},{},{}],[{},{},{}]],
     [[{},{},{}],[{},{},{}]],
     [[{},{},{}],[{},{},{}]],
     [[{},{},{}],[{},{},{}]],
     [[{},{},{}],[{},{},{}]]]


def generateDist(m, s, df):
    m['FGM'] = df['FGM'].mean()#df['FGM'].mean()
    m['FGA'] = df['FGA'].mean()
    m['FG_PCT'] = df['FG_PCT'].mean()
    m['FG3M'] = df['FG3M'].mean()
    m['FG3A'] = df['FG3A'].mean()
    m['FG3_PCT'] = df['FG3_PCT'].mean()
    m['FTM'] = df['FTM'].mean()
    m['FTA'] = df['FTA'].mean()
    m['FT_PCT'] = df['FT_PCT'].mean()
    m['OREB'] = df['OREB'].mean()
    m['DREB'] = df['DREB'].mean()
    m['REB'] = df['REB'].mean()
    m['AST'] = df['AST'].mean()
    m['TOV'] = df['TOV'].mean()
    m['STL'] = df['STL'].mean()
    m['BLK'] = df['BLK'].mean()
    m['BLKA'] = df['BLKA'].mean()
    m['PF'] = df['PF'].mean()
    m['PFD'] = df['PFD'].mean()
    m['PTS'] = df['PTS'].mean()
    m['WPCT'] = df['WPCT'].mean()
    m['FGM-'] = df['FGM-'].mean()#df['FGM'].mean()
    m['FGA-'] = df['FGA-'].mean()
    m['FG_PCT-'] = df['FG_PCT-'].mean()
    m['FG3M-'] = df['FG3M-'].mean()
    m['FG3A-'] = df['FG3A-'].mean()
    m['FG3_PCT-'] = df['FG3_PCT-'].mean()
    m['FTM-'] = df['FTM-'].mean()
    m['FTA-'] = df['FTA-'].mean()
    m['FT_PCT-'] = df['FT_PCT-'].mean()
    m['OREB-'] = df['OREB-'].mean()
    m['DREB-'] = df['DREB-'].mean()
    m['REB-'] = df['REB-'].mean()
    m['AST-'] = df['AST-'].mean()
    m['TOV-'] = df['TOV-'].mean()
    m['STL-'] = df['STL-'].mean()
    m['BLK-'] = df['BLK-'].mean()
    m['BLKA-'] = df['BLKA-'].mean()
    m['PF-'] = df['PF-'].mean()
    m['PFD-'] = df['PFD-'].mean()
    m['PTS-'] = df['PTS-'].mean()
    m['WPCT-'] = df['WPCT-'].mean()
    
    s['FGM'] = df['FGM'].std()
    s['FGA'] = df['FGA'].std()
    s['FG_PCT'] = df['FG_PCT'].mean()
    s['FG3M'] = df['FG3M'].std()
    s['FG3A'] = df['FG3A'].std()
    s['FG3_PCT'] = df['FG3_PCT'].mean()
    s['FTM'] = df['FTM'].std()
    s['FTA'] = df['FTA'].std()
    s['FT_PCT'] = df['FT_PCT'].mean()
    s['OREB'] = df['OREB'].std()
    s['DREB'] = df['DREB'].std()
    s['REB'] = df['REB'].std()
    s['AST'] = df['AST'].std()
    s['TOV'] = df['TOV'].std()
    s['STL'] = df['STL'].std()
    s['BLK'] = df['BLK'].std()
    s['BLKA'] = df['BLKA'].std()
    s['PF'] = df['PF'].std()
    s['PFD'] = df['PFD'].std()
    s['PTS'] = df['PTS'].std()
    s['WPCT'] = df['WPCT'].mean()
    s['FGM-'] = df['FGM-'].std()
    s['FGA-'] = df['FGA-'].std()
    s['FG_PCT-'] = df['FG_PCT-'].mean()
    s['FG3M-'] = df['FG3M-'].std()
    s['FG3A-'] = df['FG3A-'].std()
    s['FG3_PCT-'] = df['FG3_PCT-'].mean()
    s['FTM-'] = df['FTM-'].std()
    s['FTA-'] = df['FTA-'].std()
    s['FT_PCT-'] = df['FT_PCT-'].mean()
    s['OREB-'] = df['OREB-'].std()
    s['DREB-'] = df['DREB-'].std()
    s['REB-'] = df['REB-'].std()
    s['AST-'] = df['AST-'].std()
    s['TOV-'] = df['TOV-'].std()
    s['STL-'] = df['STL-'].std()
    s['BLK-'] = df['BLK-'].std()
    s['BLKA-'] = df['BLKA-'].std()
    s['PF-'] = df['PF-'].std()
    s['PFD-'] = df['PFD-'].std()
    s['PTS-'] = df['PTS-'].std()
    s['WPCT-'] = df['WPCT-'].mean()

for i in range(len(games)):
    generateDist(m[i][0][0],m[i][1][0], games[i])
    generateDist(m[i][0][1],m[i][1][1], games[i][games[i]['WL']=='W'])
    generateDist(m[i][0][2],m[i][1][2], games[i][games[i]['WL']=='L'])

    '''generateDist(m[0][0][0], m[0][1][0], games[0])
generateDist(m[1][0][0], m[1][1][0], games[0])
generateDist(m[2][0][0], m[2][1][0], games[0])
generateDist(m[3][0][0], m[3][1][0], games[0])
generateDist(m[4][0][0], m[4][1][0], games[0])
generateDist(m[5][0][0], m[5][1][0], games[0])
generateDist(m[6][0][0], m[6][1][0], games[0])
generateDist(m[0][0][1], m[0][1][1], games2014[games2014['WL']=='W'])
generateDist(m[1][0][1], m[1][1][1], games2015[games2015['WL']=='W'])
generateDist(m[2][0][1], m[2][1][1], games2016[games2016['WL']=='W'])
generateDist(m[3][0][1], m[3][1][1], games2017[games2017['WL']=='W'])
generateDist(m[4][0][1], m[4][1][1], games2018[games2018['WL']=='W'])
generateDist(m[5][0][1], m[5][1][1], games2019[games2019['WL']=='W'])
generateDist(m[6][0][1], m[6][1][1], games2020[games2020['WL']=='W'])
generateDist(m[0][0][2], m[0][1][2], games2014[games2014['WL']=='L'])
generateDist(m[1][0][2], m[1][1][2], games2015[games2015['WL']=='L'])
generateDist(m[2][0][2], m[2][1][2], games2016[games2016['WL']=='L'])
generateDist(m[3][0][2], m[3][1][2], games2017[games2017['WL']=='L'])
generateDist(m[4][0][2], m[4][1][2], games2018[games2018['WL']=='L'])
generateDist(m[5][0][2], m[5][1][2], games2019[games2019['WL']=='L'])
generateDist(m[6][0][2], m[6][1][2], games2020[games2020['WL']=='L'])'''

print(m[0])
# Out:
# [[{'FGM': 0.7754162448051994, 'FGA': 1.7267730671072905, 'FG_PCT': 0.450076891781936, 'FG3M': 0.16216486450321885, 'FG3A': 0.4632414740204133, 'FG3_PCT': 0.3476444263628958, 'FTM': 0.35406342178931105, 'FTA': 0.47200211437643536, 'FT_PCT': 0.7504938974776215, 'OREB': 0.2248811030360087, 'DREB': 0.66968804236818, 'REB': 0.8945691454041894, 'AST': 0.4555558803310092, 'TOV': 0.2967460376491302, 'STL': 0.15999469170696326, 'BLK': 0.09901441526355917, 'BLKA': 0.09901441526355917, 'PF': 0.41759114073147263, 'PFD': 0.4175911407314728, 'PTS': 2.067060775902932, 'WPCT': 0.501238912546396, 'FGM-': 0.7754162448051991, 'FGA-': 1.72677306710729, 'FG_PCT-': 0.45007689178193605, 'FG3M-': 0.16216486450321882, 'FG3A-': 0.4632414740204132, 'FG3_PCT-': 0.3476444263628957, 'FTM-': 0.3540634217893111, 'FTA-': 0.47200211437643524, 'FT_PCT-': 0.7504938974776216, 'OREB-': 0.2248811030360086, 'DREB-': 0.66968804236818, 'REB-': 0.8945691454041894, 'AST-': 0.4555558803310092, 'TOV-': 0.2967460376491303, 'STL-'
# ...

# %%
'''for i in range(len(games)):
    games[i] = games[i].merge(bets, how='inner', left_on=['GAME_ID', 'MATCHUP'], right_on=['game_id', 'matchup'])
    games[i] = games[i].drop(columns=['game_id','game_date','matchup','team_id','is_home','wl','w','l',
                           'min','fgm','fga','fg_pct','fg3m','fg3a','fg3_pct','ftm','fta','ft_pct',
                           'oreb','dreb','reb','ast','stl','blk','tov','pf','pts',
                           'a_team_id','season_year','season_type','season'])
'''
# Out:
# "for i in range(len(games)):\n    games[i] = games[i].merge(bets, how='inner', left_on=['GAME_ID', 'MATCHUP'], right_on=['game_id', 'matchup'])\n    games[i] = games[i].drop(columns=['game_id','game_date','matchup','team_id','is_home','wl','w','l',\n                           'min','fgm','fga','fg_pct','fg3m','fg3a','fg3_pct','ftm','fta','ft_pct',\n                           'oreb','dreb','reb','ast','stl','blk','tov','pf','pts',\n                           'a_team_id','season_year','season_type','season'])\n"

# %%
'''games[0].to_csv(r'.\data\2014-15 bets.csv')
games[1].to_csv(r'.\data\2015-16 bets.csv')
games[2].to_csv(r'.\data\2016-17 bets.csv')
games[3].to_csv(r'.\data\2017-18 bets.csv')
games[4].to_csv(r'.\data\2018-19 bets.csv')
games[5].to_csv(r'.\data\2019-20 bets.csv')
games[6].to_csv(r'.\data\2020-21 bets.csv')'''
# Out:
# "games[0].to_csv(r'.\\data\x814-15 bets.csv')\ngames[1].to_csv(r'.\\data\x815-16 bets.csv')\ngames[2].to_csv(r'.\\data\x816-17 bets.csv')\ngames[3].to_csv(r'.\\data\x817-18 bets.csv')\ngames[4].to_csv(r'.\\data\x818-19 bets.csv')\ngames[5].to_csv(r'.\\data\x819-20 bets.csv')\ngames[6].to_csv(r'.\\data\x820-21 bets.csv')"

# %%
''''''
games[0] = pd.read_csv(r'.\data\2014-15.csv', index_col=0)
games[1] = pd.read_csv(r'.\data\2015-16.csv', index_col=0)
games[2] = pd.read_csv(r'.\data\2016-17.csv', index_col=0)
games[3] = pd.read_csv(r'.\data\2017-18.csv', index_col=0)
games[4] = pd.read_csv(r'.\data\2018-19.csv', index_col=0)
games[5] = pd.read_csv(r'.\data\2019-20.csv', index_col=0)
games[6] = pd.read_csv(r'.\data\2020-21.csv', index_col=0)

# %%
''''''
home = []
away = []
for i in range(len(games)):
    home.append(games[i][games[i]['MATCHUP'].str.contains('vs.')])
    away.append(games[i][games[i]['MATCHUP'].str.contains('@')])
    
bets = []
bets.append(pd.read_csv(r'.\data\2014-15 bets.csv', index_col=0))
bets.append(pd.read_csv(r'.\data\2015-16 bets.csv', index_col=0))
bets.append(pd.read_csv(r'.\data\2016-17 bets.csv', index_col=0))
bets.append(pd.read_csv(r'.\data\2017-18 bets.csv', index_col=0))
bets.append(pd.read_csv(r'.\data\2018-19 bets.csv', index_col=0))
bets.append(pd.read_csv(r'.\data\2019-20 bets.csv', index_col=0))
bets.append(pd.read_csv(r'.\data\2020-21 bets.csv', index_col=0))

# %%
''''''
for i in range(len(bets)):
    bets[i]['Date'] = pd.to_datetime(bets[i]['Date'])
    home[i]['GAME_DATE'] = pd.to_datetime(home[i]['GAME_DATE'])
    away[i]['GAME_DATE'] = pd.to_datetime(away[i]['GAME_DATE'])
# Out:
# C:\Users\Kyle\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Kyle\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
''''''
for i in range(len(bets)):
    home[i] = home[i].merge(bets[i], how='inner', left_on=['TEAM_ABBREVIATION','GAME_DATE'], right_on=['Home','Date'])
    home[i]['Spread'] = np.sign(home[i]['MLH']) * home[i]['Spread']
    away[i] = away[i].merge(bets[i], how='inner', left_on=['TEAM_ABBREVIATION','GAME_DATE'], right_on=['Away','Date'])
    away[i]['Spread'] = np.sign(away[i]['MLA']) * away[i]['Spread']
    games[i] = home[i].append(away[i])
    games[i] = games[i].sort_values(by='GAME_DATE')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MLH'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-58ebf7143fc3> in <module>
#       2 for i in range(len(bets)):
# ...

# %%
''''''
games[0].to_csv(r'.\data\2014-15.csv')
games[1].to_csv(r'.\data\2015-16.csv')
games[2].to_csv(r'.\data\2016-17.csv')
games[3].to_csv(r'.\data\2017-18.csv')
games[4].to_csv(r'.\data\2018-19.csv')
games[5].to_csv(r'.\data\2019-20.csv')
games[6].to_csv(r'.\data\2020-21.csv')

# %%
''''''
games[0] = pd.read_csv(r'.\data\2014-15.csv', index_col=0).reset_index(drop=True)
games[1] = pd.read_csv(r'.\data\2015-16.csv', index_col=0).reset_index(drop=True)
games[2] = pd.read_csv(r'.\data\2016-17.csv', index_col=0).reset_index(drop=True)
games[3] = pd.read_csv(r'.\data\2017-18.csv', index_col=0).reset_index(drop=True)
games[4] = pd.read_csv(r'.\data\2018-19.csv', index_col=0).reset_index(drop=True)
games[5] = pd.read_csv(r'.\data\2019-20.csv', index_col=0).reset_index(drop=True)
games[6] = pd.read_csv(r'.\data\2020-21.csv', index_col=0).reset_index(drop=True)
games[4].head(50)
# Out:
#    SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0      2018-19  1610612738               BOS          Boston Celtics
# 1      2018-19  1610612744               GSW   Golden State Warriors
# 2      2018-19  1610612755               PHI      Philadelphia 76ers
# 3      2018-19  1610612760               OKC   Oklahoma City Thunder
# 4      2018-19  1610612742               DAL        Dallas Mavericks
# 5      2018-19  1610612750               MIN  Minnesota Timberwolves
# 6      2018-19  1610612749               MIL         Milwaukee Bucks
# 7      2018-19  1610612748               MIA              Miami Heat
# 8      2018-19  1610612763               MEM       Memphis Grizzlies
# 9      2018-19  1610612743               DEN          Denver Nuggets
# 10     2018-19  1610612740               NOP    New Orleans Pelicans
# 11     2018-19  1610612739               CLE     Cleveland Cavaliers
# 12     2018-19  1610612737               ATL           Atlanta Hawks
# ...

# %%
np.unique(games[6]['TEAM_ABBREVIATION'])
# Out:
# array(['ATL', 'BKN', 'BOS', 'CHA', 'CHI', 'CLE', 'DAL', 'DEN', 'DET',
#        'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN',
#        'NOP', 'NYK', 'OKC', 'ORL', 'PHI', 'PHX', 'POR', 'SAC', 'SAS',
#        'TOR', 'UTA', 'WAS'], dtype=object)

# %%
# get previous year records
records = []

for i in range(7):
    records.append({})
    for team in teamIDs:
        df = games[i][games[i]['TEAM_ID'] == team].copy()
        records[i][team] = df.loc[df['GAME_ID'].idxmax(axis = 1)]['WPCT'].tolist()
        if isinstance(records[i][team], list):
            records[i][team] = records[i][team][1]
# access final records through records[year][teamid][1]

# %%
def reverseDict(d):
    replacement = {'FGM':'FGM-','FGA':'FGA-','FG_PCT':'FG_PCT-','FG3M':'FG3M-',
                   'FG3A':'FG3A-','FG3_PCT':'FG3_PCT-','FTM':'FTM-','FTA':'FTA-',
                   'FT_PCT':'FT_PCT-','OREB':'OREB-','DREB':'DREB-','REB':'REB-',
                   'AST':'AST-','TOV':'TOV-','STL':'STL-','BLK':'BLK-',
                   'BLKA':'BLKA-','PF':'PF-','PFD':'PFD-','WPCT':'WPCT-',
                   'FGM-':'FGM','FGA-':'FGA','FG_PCT-':'FG_PCT','FG3M-':'FG3M',
                   'FG3A-':'FG3A','FG3_PCT-':'FG3_PCT','FTM-':'FTM','FTA-':'FTA',
                   'FT_PCT-':'FT_PCT','OREB-':'OREB','DREB-':'DREB','REB-':'REB',
                   'AST-':'AST','TOV-':'TOV','STL-':'STL','BLK-':'BLK',
                   'BLKA-':'BLKA','PF-':'PF','PFD-':'PFD','WPCT-':'WPCT'}
    return pd.Series({replacement[k]:v for k, v in d.items()})

# %%
def predictor(team, gameDate):
    teamGames = [games[0][games[0]['TEAM_ABBREVIATION']==team].copy(),
                 games[1][games[1]['TEAM_ABBREVIATION']==team].copy(),
                 games[2][games[2]['TEAM_ABBREVIATION']==team].copy(),
                 games[3][games[3]['TEAM_ABBREVIATION']==team].copy(),
                 games[4][games[4]['TEAM_ABBREVIATION']==team].copy(),
                 games[5][games[5]['TEAM_ABBREVIATION']==team].copy(),
                 games[6][games[6]['TEAM_ABBREVIATION']==team].copy()]
    for i in range(len(teamGames)):
        teamGames[i]['GAME_DATE'] = teamGames[i]['GAME_DATE'].apply(lambda x: x[:10])
        teamGames[i] = teamGames[i][teamGames[i]['GAME_DATE'] < gameDate]
    teamID = teamGames[0].iloc[0]['TEAM_ID']
    # get current season from date
    year = 0
    for i in range(len(teamGames)):
        if (len(teamGames[i]) == 0):
            year = i-1
            break
        year = i
    wprev = 0
    wcurr = 0
    if (len(teamGames[year]) < 5):
        wprev = 0.2*(5-len(teamGames[year]))
        wcurr = 0.2*len(teamGames[year])
    else: 
        wcurr = 1
        teamGames[year] = teamGames[year][-5:]
    avs = teamGames[year][['FGM','FGA','FG_PCT','FG3M','FG3A','FG3_PCT','FTM','FTA','FT_PCT','OREB','DREB','REB','AST','TOV','STL','BLK','BLKA','PF','PFD','WPCT','FGM-','FGA-','FG_PCT-','FG3M-','FG3A-','FG3_PCT-','FTM-','FTA-','FT_PCT-','OREB-','DREB-','REB-','AST-','TOV-','STL-','BLK-','BLKA-','PF-','PFD-','WPCT-']].mean()
    for i, v in avs.items():
        if (i != 'WPCT'):
            avs = avs.replace(v, wcurr*v + wprev*m[year][0][0][i])
        else:
            avs = avs.replace(v, wcurr*v + wprev*records[year-1][teamID])
    return avs

# %%
# generate multivariate linear regression models for each prior year 
# these values are what predictor averages are put into for point total
from sklearn import linear_model
reg = linear_model.LinearRegression()
for i in range(4):
    gamesR = games[i][['FGM','FGA','FG_PCT','FG3M','FG3A','FG3_PCT','FTM','FTA','FT_PCT','OREB','DREB','REB','AST','TOV','STL','BLK','BLKA','PF','PFD','WPCT','FGM-','FGA-','FG_PCT-','FG3M-','FG3A-','FG3_PCT-','FTM-','FTA-','FT_PCT-','OREB-','DREB-','REB-','AST-','TOV-','STL-','BLK-','BLKA-','PF-','PFD-','WPCT-']].copy()
    x=gamesR[gamesR.columns.tolist()].values
    y=games[i]['PTS']
    reg.fit(x, y)

# %%
reg.predict([predictor('UTA', '2018-12-29').tolist()])
# Out:
# array([2.28333333])

# %%
print(reg.predict([predictor('UTA', '2018-12-29').tolist()]))
print(reg.predict([predictor('NYK', '2018-12-29').tolist()]))
# Out:
# [2.28333333]
# [2.15416667]

# %%
#print('success: ' + str(success) + ' ; failure: ' + str(failure))

# %%
for i in range(4,len(games)):
    games[i]['PRED_PTS'] = games[i].apply(lambda x: reg.predict([predictor(x['TEAM_ABBREVIATION'], x['GAME_DATE']).tolist()])[0], axis = 1)
    games[i]['PRED_PTS-'] = games[i].apply(lambda x: reg.predict([predictor(x['TEAM_ABBREVIATION-'], x['GAME_DATE-']).tolist()])[0], axis = 1)

# %%
for j in range(4, len(games)):
    success = 0
    failure = 0
    for i, r in games[j][games[j]['MATCHUP'].str.contains('vs.')].iterrows():
        #eachTeam = games[4][games[4]['GAME_ID'] == r['GAME_ID']]
        if r['PRED_PTS'] > r['PRED_PTS-']:
            if r['WL'] == 'W':
                success += 1
            else:
                failure += 1
        else:
            if r['WL-'] == 'W':
                success += 1
            else:
                failure += 1
    print(str(2014+j) + ' success: ' + str(success) + ' ; failure: ' + str(failure))
# Out:
# 2018 success: 746 ; failure: 483
# 2019 success: 581 ; failure: 390
# 2020 success: 668 ; failure: 412

# %%
''''''
for j in range(4, len(games)):
    success = 0
    failure = 0
    for i, r in games[j][games[j]['MATCHUP'].str.contains('vs.')].iterrows():
        #eachTeam = games[4][games[4]['GAME_ID'] == r['GAME_ID']]
        diff = r['PRED_PTS'] - r['PRED_PTS-']
        #take team's spread
        if (diff + (r['Spread']/48) > 0):
            if (r['PLUS_MINUS']+r['Spread'] > 0):
                success += 1
            else:
                failure += 1
        else:
            if (r['PLUS_MINUS']+r['Spread'] > 0):
                failure += 1
            else:
                success += 1
    print(str(2014+j) + ' success: ' + str(success) + ' ; failure: ' + str(failure))
# Out:
# "\nfor j in range(4, len(games)):\n    success = 0\n    failure = 0\n    for i, r in games[j][games[j]['MATCHUP'].str.contains('vs.')].iterrows():\n        #eachTeam = games[4][games[4]['GAME_ID'] == r['GAME_ID']]\n        diff = r['PRED_PTS'] - r['PRED_PTS-']\n        #take team's spread\n        if (diff + (r['Spread']/48) > 0):\n            if (r['PLUS_MINUS']+r['Spread'] > 0):\n                success += 1\n            else:\n                failure += 1\n        else:\n            if (r['PLUS_MINUS']+r['Spread'] > 0):\n                failure += 1\n            else:\n                success += 1\n    print(str(2014+j) + ' success: ' + str(success) + ' ; failure: ' + str(failure))"

# %%
mTeams = {}
for team in teamIDs:
    mq = [[[{},{},{}],[{},{},{}]],
         [[{},{},{}],[{},{},{}]],
         [[{},{},{}],[{},{},{}]],
         [[{},{},{}],[{},{},{}]],
         [[{},{},{}],[{},{},{}]],
         [[{},{},{}],[{},{},{}]],
         [[{},{},{}],[{},{},{}]]]
    for i in range(len(games)):
        generateDist(mq[i][0][0],m[i][1][0], games[i][games[i]['TEAM_ID'] == team])
    mTeams[team] = mq

# %%
def predictor(team, opp, gameDate, year):
    teamGames = [games[0][games[0]['TEAM_ABBREVIATION']==team].copy()]
    oppGames = [games[0][games[0]['TEAM_ABBREVIATION']==opp].copy()]
    for i in range(1,year+1):
        teamGames.append(games[i][games[i]['TEAM_ABBREVIATION']==team].copy())
        oppGames.append(games[i][games[i]['TEAM_ABBREVIATION']==opp].copy())
        
    for i in range(len(teamGames)):
        teamGames[i]['GAME_DATE'] = teamGames[i]['GAME_DATE'].apply(lambda x: x[:10])
        teamGames[i] = teamGames[i][teamGames[i]['GAME_DATE'] < gameDate]
        oppGames[i]['GAME_DATE'] = oppGames[i]['GAME_DATE'].apply(lambda x: x[:10])
        oppGames[i] = oppGames[i][oppGames[i]['GAME_DATE'] < gameDate]
    teamID = teamGames[0].iloc[0]['TEAM_ID']
    oppID = oppGames[0].iloc[0]['TEAM_ID']
    
    wprev1 = 0
    wcurr1 = 0
    if (len(teamGames[year]) < 5):
        wprev1 = 0.2*(5-len(teamGames[year]))
        wcurr1 = 0.2*len(teamGames[year])
        #teamGames[year-1] = teamGames[year-1][20:]
    else: 
        wcurr1 = 1
        teamGames[year] = teamGames[year][-5:]
    avs1 = pd.Series([],dtype='float64')
    if (len(teamGames[year] != 0)):
        avs1 = teamGames[year][['FGM','FGA','FG_PCT','FG3M','FG3A','FG3_PCT','FTM','FTA','FT_PCT','OREB','DREB','REB','AST','TOV','STL','BLK','BLKA','PF','PFD','WPCT','FGM-','FGA-','FG_PCT-','FG3M-','FG3A-','FG3_PCT-','FTM-','FTA-','FT_PCT-','OREB-','DREB-','REB-','AST-','TOV-','STL-','BLK-','BLKA-','PF-','PFD-','WPCT-']].mean()
        for i, v in avs1.items():
            if (i != 'WPCT'):
                avs1 = avs1.replace(v, wcurr1*v + wprev1*mTeams[teamID][year-1][0][0][i])
            else:
                avs1 = avs1.replace(v, wcurr1*v + wprev1*records[year-1][teamID])
    else:
        avs1 = teamGames[year-1][['FGM','FGA','FG_PCT','FG3M','FG3A','FG3_PCT','FTM','FTA','FT_PCT','OREB','DREB','REB','AST','TOV','STL','BLK','BLKA','PF','PFD','WPCT','FGM-','FGA-','FG_PCT-','FG3M-','FG3A-','FG3_PCT-','FTM-','FTA-','FT_PCT-','OREB-','DREB-','REB-','AST-','TOV-','STL-','BLK-','BLKA-','PF-','PFD-','WPCT-']].mean()
        
    reverse1 = reverseDict(avs1)
    
    wprev2 = 0
    wcurr2 = 0
    if (len(oppGames[year]) < 5):
        wprev2 = 0.2*(5-len(oppGames[year]))
        wcurr2 = 0.2*len(oppGames[year])
        #oppGames[year-1] = oppGames[year-1][20:]
    else: 
        wcurr2 = 1
        oppGames[year] = oppGames[year][-6:]
    avs2 = pd.Series([],dtype='float64')
    if (len(oppGames[year]) != 0):
        avs2 = oppGames[year][['FGM','FGA','FG_PCT','FG3M','FG3A','FG3_PCT','FTM','FTA','FT_PCT','OREB','DREB','REB','AST','TOV','STL','BLK','BLKA','PF','PFD','WPCT','FGM-','FGA-','FG_PCT-','FG3M-','FG3A-','FG3_PCT-','FTM-','FTA-','FT_PCT-','OREB-','DREB-','REB-','AST-','TOV-','STL-','BLK-','BLKA-','PF-','PFD-','WPCT-']].mean()
        for i, v in avs2.items():
            if (i != 'WPCT'):
                avs2 = avs2.replace(v, wcurr2*v + wprev2*mTeams[oppID][year-1][0][0][i])
            else:
                avs2 = avs2.replace(v, wcurr2*v + wprev2*records[year-1][oppID])
    else:
        avs2 = oppGames[year-1][['FGM','FGA','FG_PCT','FG3M','FG3A','FG3_PCT','FTM','FTA','FT_PCT','OREB','DREB','REB','AST','TOV','STL','BLK','BLKA','PF','PFD','WPCT','FGM-','FGA-','FG_PCT-','FG3M-','FG3A-','FG3_PCT-','FTM-','FTA-','FT_PCT-','OREB-','DREB-','REB-','AST-','TOV-','STL-','BLK-','BLKA-','PF-','PFD-','WPCT-']].mean()

        
    reverse2 = reverseDict(avs2)
    #print(avs1)
    #print(reverse1)
    #print(reverse2)
    
    for i, v in avs1.items():
        avs1 = avs1.replace(v, .5*v+.5*reverse2[i])
    for i, v in avs2.items():
        avs2 = avs2.replace(v, .5*v+.5*reverse1[i])
    toreturn = pd.Series([reg.predict([avs1.tolist()])[0], reg.predict([avs2.tolist()])[0]])
    #print(avs1)
    
    print(team + ' ' + opp + ' ' + gameDate)
    print(str(toreturn))
    return toreturn

# %%
predictor('OKC', 'GSW', '2018-10-16', 4).tolist()
# Out:
# OKC GSW 2018-10-16
# 0    2.232650
# 1    2.259327
# dtype: float64
# [2.232650074142252, 2.259327474086737]

# %%
for i in range(4,len(games)):
    games[i][['PRED_PTS','PRED_PTS-']] = games[i].apply(lambda x: predictor(x['TEAM_ABBREVIATION'], x['TEAM_ABBREVIATION-'], x['GAME_DATE'], i), axis = 1)
# Out:
# BOS PHI 2018-10-16
# 0    2.166192
# 1    2.178766
# dtype: float64
# BOS PHI 2018-10-16
# 0    2.166192
# 1    2.178766
# dtype: float64
# GSW OKC 2018-10-16
# 0    2.259327
# 1    2.232650
# dtype: float64
# PHI BOS 2018-10-16
# 0    2.178766
# 1    2.166192
# dtype: float64
# OKC GSW 2018-10-16
# 0    2.232650
# 1    2.259327
# dtype: float64
# DAL PHX 2018-10-17
# 0    2.238181
# 1    2.171976
# dtype: float64
# MIN SAS 2018-10-17
# 0    2.170497
# 1    2.177476
# dtype: float64
# MIL CHA 2018-10-17
# 0    2.219215
# 1    2.225082
# dtype: float64
# MIA ORL 2018-10-17
# 0    2.187741
# 1    2.132532
# dtype: float64
# MEM IND 2018-10-17
# 0    2.114610
# 1    2.193372
# dtype: float64
# DEN LAC 2018-10-17
# 0    2.267635
# 1    2.252422
# dtype: float64
# NOP HOU 2018-10-17
# 0    2.226022
# 1    2.300893
# dtype: float64
# CLE TOR 2018-10-17
# 0    2.225291
# 1    2.296592
# dtype: float64
# ATL NYK 2018-10-17
# 0    2.192208
# 1    2.212083
# dtype: float64
# ...

# %%
'''
for j in range(4, len(games)):
    success = 0
    failure = 0
    for i, r in games[j][games[j]['MATCHUP'].str.contains('vs.')].iterrows():
        #eachTeam = games[4][games[4]['GAME_ID'] == r['GAME_ID']]
        diff = r['PRED_PTS'] - r['PRED_PTS-']
        #take team's spread
        if (diff + (r['Spread']/48) > 0):
            if (r['PLUS_MINUS']+r['Spread'] > 0):
                success += 1
            else:
                failure += 1
        else:
            if (r['PLUS_MINUS']+r['Spread'] > 0):
                failure += 1
            else:
                success += 1
    print(str(2014+j) + ' success: ' + str(success) + ' ; failure: ' + str(failure))

'''
# Out:
# "\nfor j in range(4, len(games)):\n    success = 0\n    failure = 0\n    for i, r in games[j][games[j]['MATCHUP'].str.contains('vs.')].iterrows():\n        #eachTeam = games[4][games[4]['GAME_ID'] == r['GAME_ID']]\n        diff = r['PRED_PTS'] - r['PRED_PTS-']\n        #take team's spread\n        if (diff + (r['Spread']/48) > 0):\n            if (r['PLUS_MINUS']+r['Spread'] > 0):\n                success += 1\n            else:\n                failure += 1\n        else:\n            if (r['PLUS_MINUS']+r['Spread'] > 0):\n                failure += 1\n            else:\n                success += 1\n    print(str(2014+j) + ' success: ' + str(success) + ' ; failure: ' + str(failure))\n\n"

# %%
for j in range(4, len(games)):
    success = 0
    failure = 0
    for i, r in games[j][games[j]['MATCHUP'].str.contains('vs.')].iterrows():
        #eachTeam = games[4][games[4]['GAME_ID'] == r['GAME_ID']]
        #diff = r['PRED_PTS'] - r['PRED_PTS-']
        if r['PRED_PTS'] > r['PRED_PTS-']:
            if r['WL'] == 'W':
                success += 1
            else:
                failure += 1
        else:
            if r['WL-'] == 'W':
                success += 1
            else:
                failure += 1
    print(str(2014+j) + ' success: ' + str(success) + ' ; failure: ' + str(failure))
# Out:
# 2018 success: 743 ; failure: 486
# 2019 success: 593 ; failure: 378
# 2020 success: 596 ; failure: 484

# %%
games[4][games[4]['MATCHUP'].str.contains('vs.')].head(50)
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 81       2018-19  1610612738               BOS          Boston Celtics
# 327      2018-19  1610612744               GSW   Golden State Warriors
# 1188     2018-19  1610612765               DET         Detroit Pistons
# 1024     2018-19  1610612761               TOR         Toronto Raptors
# 942      2018-19  1610612759               SAS       San Antonio Spurs
# 901      2018-19  1610612758               SAC        Sacramento Kings
# 737      2018-19  1610612754               IND          Indiana Pacers
# 696      2018-19  1610612753               ORL           Orlando Magic
# 655      2018-19  1610612752               NYK         New York Knicks
# 409      2018-19  1610612746               LAC             LA Clippers
# 368      2018-19  1610612745               HOU         Houston Rockets
# 819      2018-19  1610612756               PHX            Phoenix Suns
# ...
